# %%
import numpy as np
import os
from scipy import stats
from PIL import Image
from skimage import color
from skimage.util.dtype import dtype_range
from skimage.util import img_as_ubyte
from skimage.morphology import disk
from skimage.filters.rank import gradient
from skimage.filters import roberts, sobel, threshold_otsu
from skimage.feature import corner_harris, corner_peaks, blob_log, blob_doh, blob_dog

# %%
#This function walks through all the files in the main 50_categories folder
# to generate an iterable list of file paths to submit later for feature extraction

def directory_search(directory):
    directory_list = [] #initialize list of lists to collect features 
    subdirectories = [f for f in os.listdir(directory) if not f.startswith('.')] #ignores hidden folders
    for i in range(len(subdirectories)):
        folder = subdirectories[i]
        subdirectory = directory+folder
        files = [f for f in os.listdir(subdirectory) if not f.startswith('.')] #ignores hidden folders
        for j in range(len(files)):
            file = files[j]
            file_name = subdirectory+'/'+file
            directory_list.append(file_name)
    return directory_list

#Assemble directory List w/above function
directory = '/Users/Charlie/Desktop/tester/' #define this as YOUR path to the 50_categories folder
list_of_paths = directory_search(directory)

# %%
#Feature Extraction Function
def feature_extraction(path):
    parts = path.split('/')
    category = parts[5]
    file_name = parts[6]
    
    #Read image
    im = Image.open(path)
    image = np.array(im)
    #Basic Feature Extraction
    
    #Image Size
    y = image.shape[0]
    x = image.shape[1]

    #Image Color
    if len(image.shape) == 2: #image is grey scale
        image_gray = image
        red_val = 'nan'
        grn_val = 'nan'
        blu_val = 'nan'
        most_freq_color = 'nan' #will clear later(?)
    elif len(image.shape) == 3: #image is RGB color
    
    #Most Frequent Color (really go with 2nd most freq, many of the images will have white borders and make it the most common, which is not helpful)
        pixels = im.getcolors(x * y)
        most_frequent_pixel = pixels[1]
    #Convert RGB Values to single unique number
        most_freq_color = 65536*most_frequent_pixel[1][0] + 256*most_frequent_pixel[1][1] + most_frequent_pixel[1][2]

    #Avg Value per Color channel
        red_val = np.mean(image[:,:,0])
        grn_val = np.mean(image[:,:,1])
        blu_val = np.mean(image[:,:,2])
        grey_val = np.mean(image_gray)

    #Outsu Binary Score
    thresh = threshold_otsu(image_gray)
    binary = image_gray > thresh
    binary_per = np.sum(binary)/(x*y) #since we'll be comparing images of different sizes, its more appropriate to use percent of image converted in the binary and not total binary score (# of black pixels)

    #Sharpness and Sharpness Frequencies
    selection_element = disk(5) # matrix of n pixels with a disk shape
    sharpness = (gradient(image_gray, selection_element))
    mean_sharp=np.mean(sharpness)
    sharp = sharpness.flatten()
    shrp = np.fft.fft(sharp)
    freq = np.fft.fftfreq(shrp.size, d=1)
    avg_sharp_freq = np.mean(freq)

    #Edge Detection
    edge_roberts = roberts(image_gray)
    edge_sobel = sobel(image_gray)
    roberts_score = np.sum(edge_roberts)/(x*y) #normalize to size of image
    sobel_score = np.sum(edge_sobel)/(x*y)

    #Blobs - Difference of Gaussian [x coord, y coord, radius size]
    blobs_dog = blob_dog(image_gray, max_sigma=30, threshold=.1)
    # use this method for image coordinates for fitting if corners detection fails later
    
    #Blobs - Laplacian of Gaussian [x coord, y coord, radius size]
    blobs_log = blob_log(image_gray, max_sigma=30, num_sigma=10, threshold=.1) 
    gaussian_blobs = len(blobs_log)
    guassian_means = np.mean(blobs_log[:,2])

    #Blobs - Determinant of Hessian [x coord, y coord, radius size]
    blobs_doh = blob_doh(image_gray, max_sigma=30, threshold=.01) 
    hessain_blobs = len(blobs_doh)
    hessain_means = np.mean(blobs_doh[:,2])
    
    #Linear Fitting With Corners Detction (Linear Fit to detect corner locations, help determine shape orientation)
    coords = corner_peaks(corner_harris(image_gray), min_distance=5)
    if coords.shape[0] == 0: #for some reason, corners fails on certain images, use diff method to find feature coordinates
        coords=np.empty([len(blobs_dog),2])
        coords[:,0] = blobs_dog[:,0]
        coords[:,1] = blobs_dog[:,1]
        
    lin_slope, lin_intercept, lin_r_value, lin_p_value, lin_std_err = stats.linregress(coords[:,0],coords[:,1])
    lin_rsq_value = lin_r_value**2

    return [file_name, x, y, most_freq_color, red_val, grn_val, blu_val, grey_val,
          binary_per, mean_sharp, avg_sharp_freq, roberts_score, sobel_score,
          lin_slope, lin_intercept, lin_rsq_value, lin_p_value, lin_std_err,
          gaussian_blobs, guassian_means, hessain_blobs, hessain_means, category]

# %%
list_of_paths
# Out:
# ['/Users/Charlie/Desktop/tester/gorilla/gorilla_0016.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0002.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0003.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0017.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0001.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0015.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0029.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0028.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0014.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0038.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0004.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0010.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0011.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0005.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0039.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0013.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0007.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0006.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0012.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0075.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0061.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0049.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0101.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0115.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0129.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0128.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0114.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0100.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0048.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0060.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0074.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0089.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0062.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0076.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0116.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0102.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0103.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0117.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0077.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0063.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0088.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0098.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0067.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0073.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0113.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0107.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0106.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0112.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0072.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0066.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0099.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0058.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0070.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0064.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0138.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0104.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0110.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0111.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0105.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0139.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0065.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0071.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0059.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0097.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0083.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0054.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0040.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0068.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0120.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0134.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0108.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0109.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0135.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0121.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0069.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0041.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0055.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0082.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0096.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0080.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0094.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0043.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0057.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0137.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0123.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0122.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0136.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0056.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0042.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0095.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0081.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0085.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0091.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0046.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0052.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0132.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0126.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0127.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0133.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0053.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0047.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0090.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0084.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0092.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0086.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0079.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0051.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0045.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0119.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0125.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0131.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0130.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0124.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0118.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0044.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0050.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0078.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0087.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0093.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0037.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0023.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0022.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0036.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0020.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0034.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0008.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0140.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0141.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0009.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0035.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0021.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0019.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0025.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0031.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0030.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0024.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0018.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0032.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0026.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0027.jpg',
#  '/Users/Charlie/Desktop/tester/gorilla/gorilla_0033.jpg']

# %%
path = '/Users/Charlie/Desktop/tester/gorilla/gorilla_0128.jpg'

# %%
#Read image
im = Image.open(path)
image = np.array(im)
#Basic Feature Extraction

#Image Size
y = image.shape[0]
x = image.shape[1]

#Image Color
if len(image.shape) == 2: #image is grey scale
    image_gray = image
    red_val = 'nan'
    grn_val = 'nan'
    blu_val = 'nan'
    most_freq_color = 'nan' #will clear later
elif len(image.shape) == 3: #image is RGB color
    
    #Most Frequent Color (really go with 2nd most freq, many of the images will have white borders and make it the most common, which is not helpful)
    pixels = im.getcolors(x * y)
    most_frequent_pixel = pixels[1]
    #Convert RGB Values to single unique number
    most_freq_color = 65536*most_frequent_pixel[1][0] + 256*most_frequent_pixel[1][1] + most_frequent_pixel[1][2]

    #Avg Value per Color channel
    red_val = np.mean(image[:,:,0])
    grn_val = np.mean(image[:,:,1])
    blu_val = np.mean(image[:,:,2])

# %%
# Out:
# 'nan'

# %%
len(image.shape)
# Out:
# 2

# %%
import pandas as pd
df = pd.read_csv('category_vals',sep='\t',index_col=0)

# %%
df
# Out:
#               file name    x    y  most_freq_color     red_val     grn_val  \
# 0      gorilla_0016.jpg  319  349       16711679.0  149.408592  148.160234
# 1      gorilla_0002.jpg  340  350       16711679.0   61.931454   68.196050
# 2      gorilla_0003.jpg  400  600       16711679.0   75.804963   94.221250
# 3      gorilla_0017.jpg  768  512       16711527.0   71.609828   74.130844
# 4      gorilla_0001.jpg  300  365          65536.0   54.888630   56.712100
# 5      gorilla_0015.jpg  169  225       16711675.0   83.435792   82.722788
# 6      gorilla_0029.jpg  259  400        3428658.0   81.894575  110.468668
# 7      gorilla_0028.jpg  280  187       16711673.0  124.003571  133.906990
# 8      gorilla_0014.jpg  640  421       16711679.0   95.764196   77.646441
# 9      gorilla_0038.jpg  422  648       16711679.0  114.562175  121.172825
# 10     gorilla_0004.jpg  500  756         918784.0  103.907320   86.673569
# 11     gorilla_0010.jpg  237  350        2574916.0   71.438650   97.331790
# 12     gorilla_0011.jpg  380  500       16515059.0   98.824563  100.547195
# 13     gorilla_0005.jpg  640  427       16510400.0  105.139842  102.449989
# 14     gorilla_0039.jpg  433  371          65536.0  133.750447  129.221852
# 15     gorilla_0013.jpg  774  548        8423826.0   89.675821   89.166044
# 16     gorilla_0007.jpg  480  640       16711663.0  128.928704  128.919850
# 17     gorilla_0006.jpg  152  200        9213312.0  111.577434  100.077796
# 18     gorilla_0012.jpg  687  460       15925247.0   64.139036   67.673730
# 19     gorilla_0075.jpg  550  367       16711651.0   93.049096  109.557989
# 20     gorilla_0061.jpg  400  300       16711667.0   62.544975  101.236658
# 21     gorilla_0049.jpg  290  429        6064482.0   95.779648  115.150599
# 22     gorilla_0101.jpg  200  200       16711588.0   63.108275   95.932425
# 23     gorilla_0115.jpg  320  347       16711679.0   97.630701   90.113220
# 24     gorilla_0129.jpg  400  300        5792882.0   93.270300  101.699950
# 25     gorilla_0128.jpg  334  400              NaN         NaN         NaN
# 26     gorilla_0114.jpg  286  332       12238242.0   95.546866   97.154963
# 27     gorilla_0100.jpg  640  480       16711679.0  110.717435  120.164811
# 28     gorilla_0048.jpg  329  269       16711635.0   66.312222   80.785483
# 29     gorilla_0060.jpg  279  384          65536.0  100.201762   98.721541
# ...                 ...  ...  ...              ...         ...         ...
# 4214  elephant_0027.jpg  432  325       16711675.0   84.699558   74.542372
# 4215  elephant_0033.jpg  460  345        8754536.0  121.558607  135.127757
# 4216  elephant_0083.jpg  300  263         131584.0   55.326984   50.145754
# 4217  elephant_0054.jpg  600  400       16711667.0  117.317917  128.427263
# 4218  elephant_0040.jpg  350  342       16711679.0  221.717176  221.627001
# 4219  elephant_0068.jpg  283  390       16711665.0  178.568370  175.761937
# 4220  elephant_0069.jpg  800  525       16711679.0   94.196148  102.384567
# 4221  elephant_0041.jpg  672  448        1182208.0  106.329032   99.636011
# 4222  elephant_0055.jpg  433  350       16711679.0  190.495995  185.880066
# 4223  elephant_0082.jpg  300  234         131584.0   43.920798   40.292009
# 4224  elephant_0080.jpg  300  152        6251123.0  121.097061  115.072303
# 4225  elephant_0043.jpg  428  519       16711671.0  126.236765  100.445604
# 4226  elephant_0057.jpg  250  172       16711674.0  106.149860  117.149047
# 4227  elephant_0056.jpg  504  673       16711679.0  108.515446  103.162124
# 4228  elephant_0042.jpg  612  531       16711679.0   99.099935   94.625278
# 4229  elephant_0081.jpg  253  300       16711679.0  179.205020  174.609855
# 4230  elephant_0085.jpg  300  225       16711679.0  121.720859  116.238133
# 4231  elephant_0046.jpg  350  281       16711669.0  129.785308  133.795038
# 4232  elephant_0052.jpg  210  250       16711679.0  159.148152  176.350571
# 4233  elephant_0053.jpg  332  475       16711675.0  159.278706  132.172828
# 4234  elephant_0047.jpg  500  325       16711671.0  108.672634  100.633422
# 4235  elephant_0084.jpg  300  254       16711677.0  106.723320  103.596063
# 4236  elephant_0086.jpg  300  252       16711673.0  100.561257   92.776561
# 4237  elephant_0079.jpg  300  195          65544.0  111.462103  135.050017
# 4238  elephant_0051.jpg  750  600              NaN         NaN         NaN
# 4239  elephant_0045.jpg  400  286       16711603.0  115.995979   98.841608
# 4240  elephant_0044.jpg  266  178         459520.0  173.689427  165.675488
# 4241  elephant_0050.jpg  211  432              NaN         NaN         NaN
# 4242  elephant_0078.jpg  300  291        5192496.0  152.714307  144.503173
# 4243  elephant_0087.jpg  207  300       16711674.0   61.618953   61.377939
#
#          blu_val    grey_val  binary_per  mean_sharp    ...     lin_slope  \
# 0     140.587114    0.579920    0.458336   86.852961    ...      0.029181
# 1      72.891277    0.263543    0.252782   64.113992    ...      0.220314
# 2      84.071525    0.351278    0.394188  104.556667    ...      0.477314
# 3      64.048658    0.285758    0.100728   23.922849    ...      0.087223
# 4      47.096968    0.218162    0.271096   68.474110    ...     -0.242942
# 5      77.099855    0.323407    0.432715   99.997423    ...      0.084457
# 6      77.327394    0.400028    0.432046  160.046062    ...      0.128803
# 7     113.513789    0.511107    0.598109   93.401509    ...      0.782334
# 8      84.449106    0.321517    0.283848   65.522628    ...     -0.363492
# 9      88.831871    0.460534    0.490964   90.139979    ...     -0.145321
# 10     81.972468    0.352929    0.327693   55.916074    ...     -0.196222
# 11     93.212562    0.358951    0.399819   90.203122    ...     -0.017616
# 12     86.627795    0.388932    0.383868   49.129437    ...      0.577305
# 13     77.500809    0.396952    0.611761   32.295499    ...     -1.544225
# 14    134.998020    0.512159    0.620363   61.816151    ...     -0.306855
# 15     90.347899    0.350430    0.346918   41.989683    ...      0.086435
# 16    113.956110    0.501344    0.445586   89.896676    ...      0.204996
# 17     94.149934    0.400369    0.330033   56.819342    ...      0.099076
# 18     68.524429    0.262682    0.204259   52.915034    ...      1.481782
# 19     58.633837    0.401483    0.491330  129.861461    ...      0.238468
# 20     61.558617    0.353545    0.329367  127.784550    ...      0.242753
# 21    100.520505    0.431292    0.592420   58.845109    ...     -0.295474
# 22     74.551200    0.342807    0.277150   92.041825    ...     -0.388208
# 23     85.223676    0.358267    0.445956   94.089256    ...      0.181692
# 24    100.104792    0.391348    0.498483   39.885367    ...     -0.040565
# 25           NaN   77.202238    0.268877   55.524424    ...     -3.831357
# 26     94.023275    0.378774    0.406679   71.968058    ...      0.227313
# 27    102.415127    0.458343    0.535703   97.909238    ...      0.531428
# 28     57.655552    0.298205    0.260924   64.672987    ...     -0.290247
# 29     96.826622    0.387841    0.550254   79.008849    ...     -0.902861
# ...          ...         ...         ...         ...    ...           ...
# 4214   40.226218    0.291085    0.379387  111.829095    ...     -0.134724
# 4215   72.090744    0.500782    0.833560   46.138715    ...      0.634470
# 4216   47.061686    0.200096    0.565602   36.198771    ...     -0.540828
# 4217  111.970983    0.489726    0.507171  138.044042    ...      0.105494
# 4218  220.895539    0.868994    0.616433   43.631287    ...    -17.293935
# 4219  167.488049    0.689262    0.641325  104.269285    ...     -0.077949
# 4220   82.737912    0.389129    0.374167  105.491371    ...     -0.698993
# 4221   87.558215    0.392892    0.435441   63.100639    ...      0.164643
# 4222  173.353586    0.729246    0.712207   68.408618    ...      0.304143
# 4223   37.205199    0.160159    0.501895   37.788917    ...     -0.733407
# 4224  120.741974    0.457888    0.429803   50.813575    ...     -0.016840
# 4225   78.982790    0.409328    0.451862   76.243477    ...     -0.156751
# 4226  124.710023    0.452380    0.367233   94.935581    ...     -0.327836
# 4227   89.146536    0.405056    0.431393   67.357730    ...     -0.357082
# 4228   87.242824    0.372721    0.080752   59.207159    ...     -0.149559
# 4229  172.192569    0.687890    0.631304   59.969578    ...     -0.226144
# 4230  107.108178    0.457823    0.494874  103.853556    ...     -0.200780
# 4231  100.331947    0.511883    0.274286   64.005765    ...      0.881353
# 4232  148.399810    0.669333    0.613219  104.772076    ...      0.723163
# 4233  121.368535    0.537858    0.449822   96.476138    ...     -0.281813
# 4234  100.254289    0.401233    0.263532   82.075975    ...     -0.419479
# 4235   89.489528    0.404877    0.462795  133.227520    ...      0.552089
# 4236   84.664709    0.368023    0.342460   85.504352    ...      0.045944
# 4237  156.680513    0.516067    0.729624   52.067607    ...      0.081420
# 4238         NaN  110.083404    0.395511   55.728138    ...      0.545493
# 4239   78.538365    0.396169    0.446267   92.627439    ...     -0.466890
# 4240  148.902108    0.651643    0.574069   97.765713    ...      0.502628
# 4241         NaN  118.831633    0.403403   84.702694    ...     -0.189128
# 4242  145.772577    0.573881    0.605968   51.208717    ...     -0.177157
# 4243   47.411208    0.236950    0.279195  127.708180    ...     -0.153873
#
#       lin_intercept  lin_rsq_value   lin_p_value  lin_std_err  gaussian_blobs  \
# 0        139.067269       0.000920  8.487786e-01     0.152048             281
# 1          6.310923       0.892619  5.521501e-02     0.054033             177
# 2         32.226093       0.166816  1.393848e-04     0.119265            1437
# 3        418.910689       0.000101  9.508439e-01     1.405571             111
# 4        227.728077       0.060603  7.558269e-02     0.133936             266
# 5         74.177197       0.007359  8.019776e-01     0.326961             168
# 6        100.513676       0.035737  4.174289e-03     0.044505            1201
# 7        120.512988       0.873321  1.991678e-02     0.172027             294
# 8        452.687155       0.056416  2.500923e-02     0.159377             868
# 9        226.653694       0.080493  4.152596e-02     0.069461            1157
# 10       387.682972       0.052794  1.983318e-01     0.149279             356
# 11       163.083902       0.000409  9.219003e-01     0.177801             194
# 12        71.821922       0.685804  5.832050e-03     0.147692             204
# 13       629.028129       0.981813  1.046703e-03     0.121344              39
# 14       354.900312       0.067318  2.664729e-02     0.135552             552
# 15       439.351116       0.009160  8.216396e-01     0.366998             223
# 16       271.373458       0.111070  5.805710e-02     0.104160            1230
# 17        34.955162       0.027630  7.216959e-01     0.262853              38
# 18      -396.549575       0.186162  1.234562e-01     0.894370             254
# 19       305.250779       0.039305  2.294044e-04     0.064032            1854
# 20       157.080827       0.019771  5.492332e-02     0.125667            1638
# 21       143.218789       0.850093  5.401367e-05     0.041360             129
# 22       155.493850       0.247722  2.010202e-03     0.116020             135
# 23       143.725937       0.087443  3.912183e-02     0.085616             520
# 24       206.004666       0.000869  8.727414e-01     0.251096              26
# 25       782.139657       0.364837  2.806723e-01     2.918669             232
# 26        45.855416       0.063538  1.956583e-01     0.171145             182
# 27       122.059253       0.276460  2.503210e-14     0.064080            2286
# 28       231.161957       0.041086  3.656332e-01     0.313540             261
# 29       374.791135       0.269587  2.323905e-01     0.664616             277
# ...             ...            ...           ...          ...             ...
# 4214     170.735680       0.003789  5.450086e-01     0.221806            1336
# 4215     142.621871       0.239234  1.785762e-02     0.246897              98
# 4216     245.120577       0.184387  1.875033e-01     0.379153              62
# 4217     222.132103       0.003132  3.252617e-01     0.107071            2998
# 4218    5873.012442       0.088958  1.160595e-01    10.650954             278
# 4219     120.519548       0.007006  7.494386e-01     0.239615             622
# 4220     585.903156       0.055463  4.537611e-04     0.196270            1822
# 4221     283.246507       0.018880  1.133820e-01     0.103305             415
# 4222     148.633708       0.039657  1.701303e-01     0.218314             413
# 4223     141.586142       0.186601  1.845861e-01     0.510410              50
# 4224     143.196468       0.000072  9.708060e-01     0.454131              38
# 4225     264.815652       0.071115  3.784632e-01     0.170810             539
# 4226     187.577812       0.039959  4.119228e-01     0.389732             209
# 4227     288.773623       0.108628  1.152220e-02     0.136689             788
# 4228     406.571646       0.013466  4.817536e-01     0.210452             810
# 4229     163.260818       0.019140  5.290049e-01     0.353273             176
# 4230     126.251778       0.017373  5.209806e-01     0.308231             403
# 4231      33.209043       0.213388  4.031807e-02     0.398850             182
# 4232       5.725613       0.164342  3.493884e-03     0.235373             376
# 4233     259.490024       0.251690  9.654648e-02     0.153663             824
# 4234     320.844867       0.097184  3.680399e-03     0.140337             670
# 4235      78.572421       0.166242  4.166899e-04     0.148845            1079
# 4236     200.763368       0.001940  7.662775e-01     0.153653             228
# 4237     137.877692       0.002056  8.537663e-01     0.435074              98
# 4238     298.064219       0.131421  1.559075e-02     0.216390            1218
# 4239     254.788852       0.004171  8.792371e-01     2.945041             580
# 4240      64.157771       0.083276  9.272022e-02     0.290300             209
# 4241     159.482811       0.161864  5.574884e-03     0.064880             430
# 4242     185.663161       0.046992  4.566341e-01     0.230306              89
# 4243     147.184429       0.022357  3.269293e-01     0.155173             383
#
#       guassian_means  hessain_blobs  hessain_means  category
# 0           3.614472             36      11.919753   gorilla
# 1           2.547395              8       5.833333   gorilla
# 2           1.771360             35       5.971429   gorilla
# 3           3.902903              1      30.000000   gorilla
# 4           2.611111              7      18.031746   gorilla
# 5           2.074074              3      18.185185   gorilla
# 6           1.504394             57       5.805068   gorilla
# 7           1.679516              5      15.822222   gorilla
# 8           1.664491             16      12.881944   gorilla
# 9           2.063862             16      12.680556   gorilla
# 10          2.819288             25       7.315556   gorilla
# 11          3.458190             28       2.956349   gorilla
# 12          1.995098              3       3.148148   gorilla
# 13         10.418803              2      20.333333   gorilla
# 14          2.120773              9      22.481481   gorilla
# 15          6.259591             10      24.844444   gorilla
# 16          1.757091             12      18.453704   gorilla
# 17          3.204678              2      18.722222   gorilla
# 18          4.907262             10       9.055556   gorilla
# 19          1.643054            126       4.656966   gorilla
# 20          1.232126             30       4.544444   gorilla
# 21          3.273040              2       5.833333   gorilla
# 22          2.503704              5      11.955556   gorilla
# 23          1.557692             14       4.452381   gorilla
# 24          9.923077              0            NaN   gorilla
# 25          1.930556              6       4.759259   gorilla
# 26          3.744200              4       9.055556   gorilla
# 27          1.377758             16       7.243056   gorilla
# 28          2.123457              9      13.530864   gorilla
# 29          1.884075              5      12.600000   gorilla
# ...              ...            ...            ...       ...
# 4214        1.364188             14       8.595238  elephant
# 4215        2.315193              0            NaN  elephant
# 4216        5.261649              0            NaN  elephant
# 4217        1.352531             36       9.592593  elephant
# 4218        1.625899            138       1.303543  elephant
# 4219        1.916935             35       6.063492  elephant
# 4220        2.085864            147       7.554044  elephant
# 4221        2.164659              2      30.000000  elephant
# 4222        2.100081             14      18.492063  elephant
# 4223        6.155556              0            NaN  elephant
# 4224        7.698830              5      19.688889  elephant
# 4225        2.099979              9      16.037037  elephant
# 4226        2.048379              6      20.870370  elephant
# 4227        2.173576             25      12.084444  elephant
# 4228        1.453498             11      13.010101  elephant
# 4229        2.885732             16      16.708333  elephant
# 4230        1.695616             16       5.430556  elephant
# 4231        2.593407              3      17.111111  elephant
# 4232        1.582742             11      12.717172  elephant
# 4233        1.840750              8      17.513889  elephant
# 4234        1.793532             18      12.277778  elephant
# 4235        1.229945             10       3.255556  elephant
# 4236        2.582846             18      13.530864  elephant
# 4237        3.597506             12      11.203704  elephant
# 4238        2.121693             24      16.708333  elephant
# 4239        1.166667              7       6.063492  elephant
# 4240        2.695906              9      17.111111  elephant
# 4241        1.944186             16      13.284722  elephant
# 4242        5.272160              7      24.476190  elephant
# 4243        1.664636            295       1.196610  elephant
#
# [4244 rows x 23 columns]
